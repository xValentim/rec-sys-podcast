# %%
import requests
from pprint import pprint

endpoint = "http://localhost:1414/query"
endpoint_machine = "http://10.103.0.28:1414/query"

# %% [markdown]
# ## Bateria de testes

# %%
# Trecho retirado do vídeo -> https://www.youtube.com/watch?v=F8c422R-C1w
'''
Metadados:


Teste 1 (primeiro trecho do vídeo):
    Title: PERÍODO JOANINO PARA O ENEM
    Views count: 365927
    Publish date: 2017-06-15 00:00:00
    Author: Parabólica
    Description: Unknown
    Link video: https://www.youtube.com/watch?v=F8c422R-C1w
            
            
Teste 2 (primeiro trecho do vídeo):
    Title: HISTÓRIA GERAL #22 1ª GUERRA MUNDIAL,"Title: HISTÓRIA GERAL #22 1ª GUERRA MUNDIAL
    Views count: 539037
    Publish date: 2017-06-09 00:00:00
    Author: Parabólica
    Description: Unknown
    Link video: https://www.youtube.com/watch?v=kCKuP2OqfEs
        
        
Teste 3 (primeiro trecho do vídeo):
    Title: HISTÓRIA GERAL #23 TRATADO DE VERSALHES
    Views count: 187163
    Publish date: 2017-06-16 00:00:00
    Author: Parabólica
    Description: Unknown
    Link video: https://www.youtube.com/watch?v=T-sajvY_F4Y
'''

data_test_1 = {
    "query": "Dom João VI Ele veio para cá negociando inclusive com a Inglaterra né para vocês saberem a Marinha britânica que fez a escolta da família real até o Brasil chegaram ao Brasil você vai encontrar em vários livros falando que que você teve problema ali de de desinteria problema de piolho né o pessoal teve de arreia mesmo m né piolho mas na verdade isso tudo aconteceu porque a viagem não era tão rápida e é a primeira vez que uma nobreza portuguesa viaja a sua colônia tá a colônia e a sua colônia mais Próspera pelo menos então eles reclamaram de tudo reclamaram do desconforto da viagem porque a nobreza"
}

data_test_2 = {
    "query": "eu gosto dessa dissidência tristeza mas para estudar para entender ea primeira guerra mundial um negócio tá ganhando néné vem ganhando muito muito muito os estudos recentemente que antigamente só se falava de segunda guerra mundial eu tô aqui pra explicar a vocês porque aconteceu e como aconteceu"
}

data_test_3 = {
    "query": "foi escolhido um culpado para a guerra e o culpado é a alemanha se vocês acompanharam a nossa vídeo aula sobre a primeira guerra mundial vocês podem perceber que a alemanha estava envolvidas em todas ou quase todas as rivalidades do mundo alemanha inglaterra alemanha e rússia alemanha e frança"
}

# %%
response = requests.get(endpoint, json=data_test_1)
if response.status_code == 200:
    pprint(response.json())
else:
    pprint(response.text)
# Out:
# {'message': 'OK',
#  'results': [{'content': 'Title: PERÍODO JOANINO PARA O ENEM\n'
#                          'Views count: 365927\n'
#                          'Publish date: 2017-06-15 00:00:00\n'
#                          'Author: Parabólica\n'
#                          'Description: Unknown\n'
#                          'Link video: '
#                          'https://www.youtube.com/watch?v=F8c422R-C1w\n'
#                          '\n'
#                          'title período joanino enem views count publish date '
#                          'author parabólica description unknown link video '
#                          'httpswwwyoutubecomwatchfcr salve salve gente tudo '
#                          'bem bemvindos vídeo parabólica hoje dia videoaula '
#                          'história brasil momento decisivo vamos falar hoje '
#                          'período joanino finalzinho processo colonial '
# ...

# %%
response = requests.get(endpoint, json=data_test_2)
if response.status_code == 200:
    pprint(response.json())
else:
    pprint(response.text)
# Out:
# {'message': 'OK',
#  'results': [{'content': 'Title: HISTÓRIA GERAL #22 1ª GUERRA MUNDIAL\n'
#                          'Views count: 539037\n'
#                          'Publish date: 2017-06-09 00:00:00\n'
#                          'Author: Parabólica\n'
#                          'Description: Unknown\n'
#                          'Link video: '
#                          'https://www.youtube.com/watch?v=kCKuP2OqfEs\n'
#                          '\n'
#                          'title história geral guerra mundial views count '
#                          'publish date author parabólica description unknown '
#                          'link video httpswwwyoutubecomwatchkckupoqfes gente '
#                          'bem vindos vídeo parabólica novamente agora aula '
#                          'história geral recente fala tema importante pode '
#                          'perder nada então tudo tão importante amigos '
# ...

# %%
response = requests.get(endpoint, json=data_test_3)
if response.status_code == 200:
    pprint(response.json())
else:
    pprint(response.text)
# Out:
# {'message': 'OK',
#  'results': [{'content': 'Title: HISTÓRIA GERAL #23 TRATADO DE VERSALHES\n'
#                          'Views count: 187163\n'
#                          'Publish date: 2017-06-16 00:00:00\n'
#                          'Author: Parabólica\n'
#                          'Description: Unknown\n'
#                          'Link video: '
#                          'https://www.youtube.com/watch?v=T-sajvY_F4Y\n'
#                          '\n'
#                          'title história geral tratado versalhes views count '
#                          'publish date author parabólica description unknown '
#                          'link video httpswwwyoutubecomwatchsajvy_fy agora sim '
#                          'gente tudo bem bem vindos vídeo parabólica '
#                          'continuidade aula história geral hoje hoje certeza '
#                          'saber menor todas ponto importante gente falar eixo '
# ...
